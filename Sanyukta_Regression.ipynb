# %% [markdown]
# # Regression Analysis
#
#
# ### Libraries

# %% [markdown]
# #### Pandas, Numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Scikit learn

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# #### Warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1 Data Import

# %%
data = pd.read_csv(r"C:\Users\91997\Desktop\Resume Projects\Regression\SecondCar.csv") # Dataframe/table 1 name is 'data'
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#         fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0     Diesel  Individual       Manual  Second Owner    9.00            106001
# 1     Petrol  Individual       Manual  Second Owner    9.00            108556
# 2     Diesel  Individual       Manual   First Owner   11.00            120678
# 3     Petrol  Individual       Manual  Second Owner    9.00            122917
# 4     Petrol  Individual       Manual  Second Owner   10.00            144902
# ...      ...         ...          ...           ...     ...               ...
# 4335  Diesel      Dealer    Automatic   First Owner   11.00           9407487
# 4336  Diesel      Dealer    Automatic   First Owner    9.71           9598350
# 4337  Diesel      Dealer    Automatic   First Owner   11.00           9857238
# 4338  Petrol      Dealer    Automatic   First Owner   14.09          14235729
# 4339  Diesel      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price
# 0            100000
# 1            100000
# 2            120000
# 3            100000
# 4            130000
# ...             ...
# 4335        4950000
# 4336        4800000
# 4337        4950000
# 4338        8900000
# 4339        8150000
#
# [4340 rows x 10 columns]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Steps
#     1. Duplicate Removal
#     2. Missing Value Treatment
#     3. Unique Value Treatment
#     4. Feature Engineering
#     5. Correlation

# %% [markdown]
# ## Step 3 Duplicate Val Removal

# %%
print("Before Duplicate removal Dataframe : ")
len(data)
# Out:
# Before Duplicate removal Dataframe :
# 4340

# %%
data = data.drop_duplicates(keep = 'first') # Removes any duplicate or repeated row

# %%
print("After Duplicate removal Dataframe : ")
len(data)
# Out:
# After Duplicate removal Dataframe :
# 4340

# %% [markdown]
# ## Step 4 Missing Value Treatment

# %%
missing_value_df = pd.DataFrame(data.isna().sum(), columns = ['Missing_Value_Count']) # table 2 created by us
missing_value_df
# Out:
#                   Missing_Value_Count
# name                                0
# year                                0
# km_driven                           0
# fuel                                3
# seller_type                         2
# transmission                        2
# owner                               3
# Rating                              4
# ExShowroom Price                    0
# selling_price                       0

# %%
print(100*data.isna().sum()/len(data), "%") # Sum of null values from entire df divided by length of entire df
# Out:
# name                0.000000
# year                0.000000
# km_driven           0.000000
# fuel                0.069124
# seller_type         0.046083
# transmission        0.046083
# owner               0.069124
# Rating              0.092166
# ExShowroom Price    0.000000
# selling_price       0.000000
# dtype: float64 %

# %%
missing_value_df['Percentage'] = 100*data.isna().sum()/len(data)
missing_value_df
# Out:
#                   Missing_Value_Count  Percentage
# name                                0    0.000000
# year                                0    0.000000
# km_driven                           0    0.000000
# fuel                                3    0.069124
# seller_type                         2    0.046083
# transmission                        2    0.046083
# owner                               3    0.069124
# Rating                              4    0.092166
# ExShowroom Price                    0    0.000000
# selling_price                       0    0.000000

# %% [markdown]
# ### Note : We check if the missing value is less than 75%. If more than 75% then delete the entrie column.

# %%
missing_value_df[missing_value_df['Percentage']>75]
# Out:
# Empty DataFrame
# Columns: [Missing_Value_Count, Percentage]
# Index: []

# %%
#columns_to_be_deleted = list(missing_value_df[missing_value_df['Percentage']>75].index)
#data.drop(columns = columns_to_be_deleted, inplace = True)

# %% [markdown]
# #### Median Mode

# %%
data['fuel'].mode()[0]   # Mode : Most repeating/occuring value in the column, for textutal/object type data we use mode
# Out:
# 'Diesel'

# %%
data['name'].mode()[0]
# Out:
# 'Maruti Swift Dzire VDI'

# %%
data['km_driven'].median() # Median : For numeric type data
# Out:
# 60000.0

# %% [markdown]
# #### We fill in the null cells of the dataframe

# %%
for col in data.columns: 
    print(col, data[col].dtype) ## The datatype of each columns is printed. int,float are numeric dtype
# Out:
# name object
# year int64
# km_driven int64
# fuel object
# seller_type object
# transmission object
# owner object
# Rating float64
# ExShowroom Price int64
# selling_price int64

# %% [markdown]
# ### Null values of every column are replaced according to the column's dtype.
# #### For Numeric dtype we replace the empty cell using median function
# #### For Object/textual dtype we replace the empty cell using mode function

# %%
for col in data.columns:
    if data[col].dtype == 'object': # We access data of each column using for loop and check if dtype is object
        print(col, '--->', data[col].dtype, '--->', data[col].mode([0])) 
        data[col].fillna(data[col].mode()[0], inplace = True)
        # We fill/replace null values using fillna by the mode value obtained from the respective columns
# Out:
# name ---> object ---> 0    Maruti Swift Dzire VDI
# Name: name, dtype: object
# fuel ---> object ---> 0    Diesel
# Name: fuel, dtype: object
# seller_type ---> object ---> 0    Individual
# Name: seller_type, dtype: object
# transmission ---> object ---> 0    Manual
# Name: transmission, dtype: object
# owner ---> object ---> 0    First Owner
# Name: owner, dtype: object

# %%
for col in data.columns:
    if data[col].dtype != 'object':  # We access data of each column using for loop and check if dtype is not object
        print(col, '--->', data[col].dtype, '--->', data[col].median())
        data[col].fillna(data[col].median(), inplace = True)
        # We fill/replace null values using fillna by the median value obtained from the respective columns
# Out:
# year ---> int64 ---> 2014.0
# km_driven ---> int64 ---> 60000.0
# Rating ---> float64 ---> 12.0
# ExShowroom Price ---> int64 ---> 596055.0
# selling_price ---> int64 ---> 350000.0

# %% [markdown]
# #### Now we cross check how many missing/null values we have. Refer ln[10] data.isna().sum()

# %%
data.isna().sum() # Step 4 ends
# Out:
# name                0
# year                0
# km_driven           0
# fuel                0
# seller_type         0
# transmission        0
# owner               0
# Rating              0
# ExShowroom Price    0
# selling_price       0
# dtype: int64

# %% [markdown]
# ## Step 5 Unique Value Treatment

# %% [markdown]
# #### Adding a dummy column now

# %%
data['Dummy'] = 'Sanyukta'
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#         fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0     Diesel  Individual       Manual  Second Owner    9.00            106001
# 1     Petrol  Individual       Manual  Second Owner    9.00            108556
# 2     Diesel  Individual       Manual   First Owner   11.00            120678
# 3     Petrol  Individual       Manual  Second Owner    9.00            122917
# 4     Petrol  Individual       Manual  Second Owner   10.00            144902
# ...      ...         ...          ...           ...     ...               ...
# 4335  Diesel      Dealer    Automatic   First Owner   11.00           9407487
# 4336  Diesel      Dealer    Automatic   First Owner    9.71           9598350
# 4337  Diesel      Dealer    Automatic   First Owner   11.00           9857238
# 4338  Petrol      Dealer    Automatic   First Owner   14.09          14235729
# 4339  Diesel      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price     Dummy
# 0            100000  Sanyukta
# 1            100000  Sanyukta
# 2            120000  Sanyukta
# 3            100000  Sanyukta
# 4            130000  Sanyukta
# ...             ...       ...
# 4335        4950000  Sanyukta
# 4336        4800000  Sanyukta
# 4337        4950000  Sanyukta
# 4338        8900000  Sanyukta
# 4339        8150000  Sanyukta
#
# [4340 rows x 11 columns]

# %% [markdown]
# #### If the entire columns has
#          1. Only one value throughout
#          2. All values different
#          Delete the entire Column

# %%
for col in data.columns:
    print(col, data[col].nunique())
# Out:
# name 1491
# year 27
# km_driven 770
# fuel 5
# seller_type 3
# transmission 2
# owner 5
# Rating 566
# ExShowroom Price 4331
# selling_price 445
# Dummy 1

# %% [markdown]
# #### Dataset size 4340
#     1. 1
#     2. 4340 & they are object/textual dtype
#     delete

# %%
for col in data.columns:
    if(data[col].nunique()==1):
        del data[col]
    elif(data[col].nunique()==len(data) & (data[col].dtype == 'object')):
         del data[col]

# %%
len(data)
# Out:
# 4340

# %%
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#         fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0     Diesel  Individual       Manual  Second Owner    9.00            106001
# 1     Petrol  Individual       Manual  Second Owner    9.00            108556
# 2     Diesel  Individual       Manual   First Owner   11.00            120678
# 3     Petrol  Individual       Manual  Second Owner    9.00            122917
# 4     Petrol  Individual       Manual  Second Owner   10.00            144902
# ...      ...         ...          ...           ...     ...               ...
# 4335  Diesel      Dealer    Automatic   First Owner   11.00           9407487
# 4336  Diesel      Dealer    Automatic   First Owner    9.71           9598350
# 4337  Diesel      Dealer    Automatic   First Owner   11.00           9857238
# 4338  Petrol      Dealer    Automatic   First Owner   14.09          14235729
# 4339  Diesel      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price
# 0            100000
# 1            100000
# 2            120000
# 3            100000
# 4            130000
# ...             ...
# 4335        4950000
# 4336        4800000
# 4337        4950000
# 4338        8900000
# 4339        8150000
#
# [4340 rows x 10 columns]

# %%
for col in data.columns:
    print(col, data[col].nunique())
# Out:
# name 1491
# year 27
# km_driven 770
# fuel 5
# seller_type 3
# transmission 2
# owner 5
# Rating 566
# ExShowroom Price 4331
# selling_price 445

# %% [markdown]
# ## Step 6 Feature Engineering - Variety Reduction

# %%
data['name']
# Out:
# 0                          Tata Indica Vista Aqua 1.4 TDI
# 1                                       Tata Nano Lx BSIV
# 2                        Tata Indica Vista Aqua TDI BSIII
# 3                                Maruti Wagon R LXI Minor
# 4                                       Chevrolet Beat LT
#                               ...
# 4335                              BMW X5 xDrive 30d xLine
# 4336                        BMW 5 Series 520d Luxury Line
# 4337                              BMW X5 xDrive 30d xLine
# 4338             Audi RS7 2015-2019 Sportback Performance
# 4339    Mercedes-Benz S-Class S 350d Connoisseurs Edition
# Name: name, Length: 4340, dtype: object

# %%
data['name'].str.split(" ").str[0] # Splitting and extracting only the first word/company name
# Out:
# 0                Tata
# 1                Tata
# 2                Tata
# 3              Maruti
# 4           Chevrolet
#             ...
# 4335              BMW
# 4336              BMW
# 4337              BMW
# 4338             Audi
# 4339    Mercedes-Benz
# Name: name, Length: 4340, dtype: object

# %%
data['name_after_split'] = data['name'].str.split(" ").str[0] # Creating a new column in the dataframe where we store
# first name 
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#         fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0     Diesel  Individual       Manual  Second Owner    9.00            106001
# 1     Petrol  Individual       Manual  Second Owner    9.00            108556
# 2     Diesel  Individual       Manual   First Owner   11.00            120678
# 3     Petrol  Individual       Manual  Second Owner    9.00            122917
# 4     Petrol  Individual       Manual  Second Owner   10.00            144902
# ...      ...         ...          ...           ...     ...               ...
# 4335  Diesel      Dealer    Automatic   First Owner   11.00           9407487
# 4336  Diesel      Dealer    Automatic   First Owner    9.71           9598350
# 4337  Diesel      Dealer    Automatic   First Owner   11.00           9857238
# 4338  Petrol      Dealer    Automatic   First Owner   14.09          14235729
# 4339  Diesel      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price name_after_split
# 0            100000             Tata
# 1            100000             Tata
# 2            120000             Tata
# 3            100000           Maruti
# 4            130000        Chevrolet
# ...             ...              ...
# 4335        4950000              BMW
# 4336        4800000              BMW
# 4337        4950000              BMW
# 4338        8900000             Audi
# 4339        8150000    Mercedes-Benz
#
# [4340 rows x 11 columns]

# %%
for col in data.columns:
    print(col, data[col].nunique())
# Out:
# name 1491
# year 27
# km_driven 770
# fuel 5
# seller_type 3
# transmission 2
# owner 5
# Rating 566
# ExShowroom Price 4331
# selling_price 445
# name_after_split 29

# %%
round(data.describe(), 2)
# Out:
#           year  km_driven   Rating  ExShowroom Price  selling_price
# count  4340.00    4340.00  4340.00           4340.00        4340.00
# mean   2013.09   66215.78    11.97         845380.89      504127.31
# std       4.22   46644.10     1.91         884840.54      578548.74
# min    1992.00       1.00     9.00         106001.00       20000.00
# 25%    2011.00   35000.00    10.02         445389.50      208749.75
# 50%    2014.00   60000.00    12.00         596055.00      350000.00
# 75%    2016.00   90000.00    13.76         946243.00      600000.00
# max    2020.00  806599.00    15.00       15538153.00     8900000.00

# %%
for col in data.columns:
    if data[col].dtype != 'object':
        print("Auto feature Engg -->>", col)
# Out:
# Auto feature Engg -->> year
# Auto feature Engg -->> km_driven
# Auto feature Engg -->> Rating
# Auto feature Engg -->> ExShowroom Price
# Auto feature Engg -->> selling_price

# %%
for col in data.columns:
    if data[col].dtype != 'object':
        print("Auto feature Engg -->>", col)
        new_col_name = col + '_bin'
        data[new_col_name] = pd.qcut(data[col], 4, labels = ['b1','b2','b3','b4'])
# Out:
# Auto feature Engg -->> year
# Auto feature Engg -->> km_driven
# Auto feature Engg -->> Rating
# Auto feature Engg -->> ExShowroom Price
# Auto feature Engg -->> selling_price

# %%
data
# Out:
#                                                    name  year  km_driven  \
# 0                        Tata Indica Vista Aqua 1.4 TDI  2010     120000
# 1                                     Tata Nano Lx BSIV  2012      50000
# 2                      Tata Indica Vista Aqua TDI BSIII  2011      70000
# 3                              Maruti Wagon R LXI Minor  2010      80000
# 4                                     Chevrolet Beat LT  2010      80000
# ...                                                 ...   ...        ...
# 4335                            BMW X5 xDrive 30d xLine  2019      30000
# 4336                      BMW 5 Series 520d Luxury Line  2019      12999
# 4337                            BMW X5 xDrive 30d xLine  2019      30000
# 4338           Audi RS7 2015-2019 Sportback Performance  2016      13000
# 4339  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017       6500
#
#         fuel seller_type transmission         owner  Rating  ExShowroom Price  \
# 0     Diesel  Individual       Manual  Second Owner    9.00            106001
# 1     Petrol  Individual       Manual  Second Owner    9.00            108556
# 2     Diesel  Individual       Manual   First Owner   11.00            120678
# 3     Petrol  Individual       Manual  Second Owner    9.00            122917
# 4     Petrol  Individual       Manual  Second Owner   10.00            144902
# ...      ...         ...          ...           ...     ...               ...
# 4335  Diesel      Dealer    Automatic   First Owner   11.00           9407487
# 4336  Diesel      Dealer    Automatic   First Owner    9.71           9598350
# 4337  Diesel      Dealer    Automatic   First Owner   11.00           9857238
# 4338  Petrol      Dealer    Automatic   First Owner   14.09          14235729
# 4339  Diesel      Dealer    Automatic   First Owner    9.00          15538153
#
#       selling_price name_after_split year_bin km_driven_bin Rating_bin  \
# 0            100000             Tata       b1            b4         b1
# 1            100000             Tata       b2            b2         b1
# 2            120000             Tata       b1            b3         b2
# 3            100000           Maruti       b1            b3         b1
# 4            130000        Chevrolet       b1            b3         b1
# ...             ...              ...      ...           ...        ...
# 4335        4950000              BMW       b4            b1         b2
# 4336        4800000              BMW       b4            b1         b1
# 4337        4950000              BMW       b4            b1         b2
# 4338        8900000             Audi       b3            b1         b4
# 4339        8150000    Mercedes-Benz       b4            b1         b1
#
#      ExShowroom Price_bin selling_price_bin
# 0                      b1                b1
# 1                      b1                b1
# 2                      b1                b1
# 3                      b1                b1
# 4                      b1                b1
# ...                   ...               ...
# 4335                   b4                b4
# 4336                   b4                b4
# 4337                   b4                b4
# 4338                   b4                b4
# 4339                   b4                b4
#
# [4340 rows x 16 columns]

# %% [markdown]
# ## Step 7 Label Encoding

# %%
LN = LabelEncoder() # We convert all the values in terms of meaningful digits which are assorted using bins

# %%
for col in data.columns:
    if ( data[col].dtype == 'object') | hasattr(data[col], 'cat'):
        data[col] = LN.fit_transform(data[col])

# %%
data
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  Rating  \
# 0     1228  2010     120000     1            1             1      2    9.00
# 1     1283  2012      50000     4            1             1      2    9.00
# 2     1229  2011      70000     1            1             1      0   11.00
# 3     1041  2010      80000     4            1             1      2    9.00
# 4       56  2010      80000     4            1             1      2   10.00
# ...    ...   ...        ...   ...          ...           ...    ...     ...
# 4335    39  2019      30000     1            0             0      0   11.00
# 4336    30  2019      12999     1            0             0      0    9.71
# 4337    39  2019      30000     1            0             0      0   11.00
# 4338    25  2016      13000     4            0             0      0   14.09
# 4339  1097  2017       6500     1            0             0      0    9.00
#
#       ExShowroom Price  selling_price  name_after_split  year_bin  \
# 0               106001         100000                25         0
# 1               108556         100000                25         1
# 2               120678         120000                25         0
# 3               122917         100000                18         0
# 4               144902         130000                 3         0
# ...                ...            ...               ...       ...
# 4335           9407487        4950000                 2         3
# 4336           9598350        4800000                 2         3
# 4337           9857238        4950000                 2         3
# 4338          14235729        8900000                 1         2
# 4339          15538153        8150000                19         3
#
#       km_driven_bin  Rating_bin  ExShowroom Price_bin  selling_price_bin
# 0                 3           0                     0                  0
# 1                 1           0                     0                  0
# 2                 2           1                     0                  0
# 3                 2           0                     0                  0
# 4                 2           0                     0                  0
# ...             ...         ...                   ...                ...
# 4335              0           1                     3                  3
# 4336              0           0                     3                  3
# 4337              0           1                     3                  3
# 4338              0           3                     3                  3
# 4339              0           0                     3                  3
#
# [4340 rows x 16 columns]

# %% [markdown]
# ## Step 8 Correlation

# %%
corr = 100*data.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_e528f_row0_col0, #T_e528f_row1_col1, #T_e528f_row2_col2, #T_e528f_row3_col3, #T_e528f_row4_col4, #T_e528f_row5_col5, #T_e528f_row6_col6, #T_e528f_row7_col7, #T_e528f_row8_col8, #T_e528f_row9_col9, #T_e528f_row10_col10, #T_e528f_row11_col11, #T_e528f_row12_col12, #T_e528f_row13_col13, #T_e528f_row14_col14, #T_e528f_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e528f_row0_col1, #T_e528f_row3_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_e528f_row0_col2, #T_e528f_row4_col6, #T_e528f_row10_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_e528f_row0_col3 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e528f_row0_col4, #T_e528f_row1_col5, #T_e528f_row4_col8, #T_e528f_row7_col15 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e528f_row0_col5, #T_e528f_row5_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_e528f_row0_col6, #T_e528f_row0_col11, #T_e528f_row13_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_e528f_row0_col7, #T_e528f_row1_col2, #T_e528f_row2_col1, #T_e528f_row2_col3, #T_e528f_row2_col11 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e528f_row0_col8, #T_e528f_row0_col9 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_e528f_row0_col10 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_e528f_row0_col12 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_e528f_row0_col13, #T_e528f_row5_col13, #T_e528f_row10_col13, #T_e528f_row14_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_e528f_row0_col14, #T_e528f_row8_col2, #T_e528f_row10_col14 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e528f_row0_col15, #T_e528f_row10_col15, #T_e528f_row11_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e528f_row1_col0, #T_e528f_row6_col7, #T_e528f_row12_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e528f_row1_col3, #T_e528f_row3_col12 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e528f_row1_col4, #T_e528f_row1_col12, #T_e528f_row5_col7, #T_e528f_row6_col1, #T_e528f_row10_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e528f_row1_col6, #T_e528f_row2_col13, #T_e528f_row4_col13, #T_e528f_row9_col0, #T_e528f_row12_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e528f_row1_col7, #T_e528f_row1_col13, #T_e528f_row2_col7, #T_e528f_row4_col7, #T_e528f_row8_col4, #T_e528f_row8_col13, #T_e528f_row15_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e528f_row1_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_e528f_row1_col9 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_e528f_row1_col10, #T_e528f_row2_col15, #T_e528f_row11_col4, #T_e528f_row14_col13 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e528f_row1_col11, #T_e528f_row11_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_e528f_row1_col14 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_e528f_row1_col15 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_e528f_row2_col0, #T_e528f_row9_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e528f_row2_col4, #T_e528f_row4_col10, #T_e528f_row5_col1, #T_e528f_row6_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e528f_row2_col5 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_e528f_row2_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_e528f_row2_col8 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e528f_row2_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e528f_row2_col10 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e528f_row2_col12 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_e528f_row2_col14 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_e528f_row3_col0, #T_e528f_row3_col10, #T_e528f_row3_col15, #T_e528f_row5_col8, #T_e528f_row5_col9, #T_e528f_row5_col14, #T_e528f_row9_col4, #T_e528f_row9_col5, #T_e528f_row9_col7, #T_e528f_row9_col13, #T_e528f_row11_col2, #T_e528f_row11_col6, #T_e528f_row11_col12, #T_e528f_row12_col1, #T_e528f_row12_col11, #T_e528f_row15_col3, #T_e528f_row15_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e528f_row3_col1, #T_e528f_row5_col11, #T_e528f_row6_col3, #T_e528f_row7_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e528f_row3_col2, #T_e528f_row6_col10, #T_e528f_row14_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_e528f_row3_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e528f_row3_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_e528f_row3_col7, #T_e528f_row3_col13, #T_e528f_row3_col14, #T_e528f_row8_col5, #T_e528f_row9_col10, #T_e528f_row11_col7, #T_e528f_row11_col13 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e528f_row3_col8, #T_e528f_row12_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e528f_row3_col9, #T_e528f_row10_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e528f_row3_col11, #T_e528f_row7_col9 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_e528f_row4_col0, #T_e528f_row6_col9, #T_e528f_row12_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e528f_row4_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_e528f_row4_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_e528f_row4_col3, #T_e528f_row5_col3, #T_e528f_row5_col4, #T_e528f_row10_col8, #T_e528f_row10_col9 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_e528f_row4_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_e528f_row4_col9, #T_e528f_row13_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e528f_row4_col11, #T_e528f_row7_col6, #T_e528f_row13_col6 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_e528f_row4_col12, #T_e528f_row12_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_e528f_row4_col14, #T_e528f_row9_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e528f_row4_col15, #T_e528f_row15_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_e528f_row5_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e528f_row5_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e528f_row5_col10, #T_e528f_row12_col9 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_e528f_row5_col12 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_e528f_row5_col15, #T_e528f_row8_col7, #T_e528f_row8_col10, #T_e528f_row15_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_e528f_row6_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_e528f_row6_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_e528f_row6_col4, #T_e528f_row13_col14 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_e528f_row6_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_e528f_row6_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e528f_row6_col12, #T_e528f_row8_col11 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_e528f_row6_col13, #T_e528f_row11_col0, #T_e528f_row12_col15 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e528f_row6_col14, #T_e528f_row12_col14, #T_e528f_row15_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e528f_row6_col15, #T_e528f_row8_col0, #T_e528f_row12_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e528f_row7_col0, #T_e528f_row13_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e528f_row7_col1, #T_e528f_row7_col2, #T_e528f_row10_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_e528f_row7_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e528f_row7_col5, #T_e528f_row13_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_e528f_row7_col8, #T_e528f_row13_col8 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_e528f_row7_col10, #T_e528f_row13_col10 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e528f_row7_col11, #T_e528f_row13_col12 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e528f_row7_col12, #T_e528f_row13_col11 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e528f_row7_col13, #T_e528f_row13_col7 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_e528f_row7_col14 {
#   background-color: #94b6f

# %%
data.drop(columns = ['name', 'Rating', 'ExShowroom Price'], inplace = True)

# %%
corr = 100*data.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_e6c3a_row0_col0, #T_e6c3a_row1_col1, #T_e6c3a_row2_col2, #T_e6c3a_row3_col3, #T_e6c3a_row4_col4, #T_e6c3a_row5_col5, #T_e6c3a_row6_col6, #T_e6c3a_row7_col7, #T_e6c3a_row8_col8, #T_e6c3a_row9_col9, #T_e6c3a_row10_col10, #T_e6c3a_row11_col11, #T_e6c3a_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e6c3a_row0_col1, #T_e6c3a_row1_col0, #T_e6c3a_row1_col2, #T_e6c3a_row1_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e6c3a_row0_col2, #T_e6c3a_row2_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e6c3a_row0_col3, #T_e6c3a_row0_col9, #T_e6c3a_row5_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e6c3a_row0_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e6c3a_row0_col5, #T_e6c3a_row1_col10, #T_e6c3a_row3_col10, #T_e6c3a_row9_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e6c3a_row0_col6 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_e6c3a_row0_col7, #T_e6c3a_row1_col12, #T_e6c3a_row8_col3, #T_e6c3a_row11_col10 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e6c3a_row0_col8, #T_e6c3a_row8_col0 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_e6c3a_row0_col10, #T_e6c3a_row12_col10 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e6c3a_row0_col11 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_e6c3a_row0_col12 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_e6c3a_row1_col3, #T_e6c3a_row3_col7, #T_e6c3a_row4_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e6c3a_row1_col4 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_e6c3a_row1_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_e6c3a_row1_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e6c3a_row1_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e6c3a_row1_col9 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_e6c3a_row1_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_e6c3a_row2_col0, #T_e6c3a_row4_col8, #T_e6c3a_row5_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e6c3a_row2_col1, #T_e6c3a_row5_col7, #T_e6c3a_row11_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_e6c3a_row2_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e6c3a_row2_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_e6c3a_row2_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_e6c3a_row2_col6, #T_e6c3a_row7_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e6c3a_row2_col7, #T_e6c3a_row2_col12, #T_e6c3a_row4_col6, #T_e6c3a_row4_col11, #T_e6c3a_row6_col3, #T_e6c3a_row6_col4, #T_e6c3a_row6_col10, #T_e6c3a_row8_col1, #T_e6c3a_row8_col5, #T_e6c3a_row8_col9, #T_e6c3a_row9_col0, #T_e6c3a_row9_col8, #T_e6c3a_row12_col2, #T_e6c3a_row12_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e6c3a_row2_col8 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_e6c3a_row2_col10, #T_e6c3a_row2_col11, #T_e6c3a_row6_col7, #T_e6c3a_row8_col10 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e6c3a_row3_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_e6c3a_row3_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_e6c3a_row3_col2, #T_e6c3a_row4_col2, #T_e6c3a_row4_col3, #T_e6c3a_row7_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_e6c3a_row3_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_e6c3a_row3_col5, #T_e6c3a_row7_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_e6c3a_row3_col6, #T_e6c3a_row10_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e6c3a_row3_col8, #T_e6c3a_row10_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_e6c3a_row3_col9, #T_e6c3a_row9_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_e6c3a_row3_col11, #T_e6c3a_row6_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e6c3a_row3_col12, #T_e6c3a_row12_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_e6c3a_row4_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_e6c3a_row4_col5 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e6c3a_row4_col7, #T_e6c3a_row9_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_e6c3a_row4_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_e6c3a_row4_col10, #T_e6c3a_row7_col10, #T_e6c3a_row11_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_e6c3a_row4_col12 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_e6c3a_row5_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_e6c3a_row5_col3, #T_e6c3a_row10_col11 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_e6c3a_row5_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_e6c3a_row5_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e6c3a_row5_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e6c3a_row5_col9 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_e6c3a_row5_col10, #T_e6c3a_row9_col12 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e6c3a_row5_col11, #T_e6c3a_row9_col11 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e6c3a_row5_col12 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e6c3a_row6_col0, #T_e6c3a_row8_col11, #T_e6c3a_row11_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_e6c3a_row6_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e6c3a_row6_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e6c3a_row6_col8 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_e6c3a_row6_col9, #T_e6c3a_row9_col7, #T_e6c3a_row11_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_e6c3a_row6_col11 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_e6c3a_row6_col12, #T_e6c3a_row11_col6 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_e6c3a_row7_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_e6c3a_row7_col3, #T_e6c3a_row10_col12 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_e6c3a_row7_col4 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_e6c3a_row7_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_e6c3a_row7_col8, #T_e6c3a_row10_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_e6c3a_row7_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_e6c3a_row7_col11 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e6c3a_row7_col12, #T_e6c3a_row8_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e6c3a_row8_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e6c3a_row8_col6 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_e6c3a_row8_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e6c3a_row8_col12 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_e6c3a_row9_col1 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_e6c3a_row9_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e6c3a_row9_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e6c3a_row9_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_e6c3a_row10_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_e6c3a_row10_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_e6c3a_row10_col4 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_e6c3a_row10_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_e6c3a_row10_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e6c3a_row10_col8 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e6c3a_row10_col9 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e6c3a_row11_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e6c3a_row11_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_e6c3a_row11_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e6c3a_row11_col8 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_e6c3a_row11_col9 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_e6c3a_row11_col12 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_e6c3a_row12_col0, #T_e6c3a_row12_col8 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_e6c3a_row12_col1, #T_e6c3a_row12_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_e6c3a_row12_col5 {
#   background-color: #4f69d9;

# %% [markdown]
# ## Step 9 Train Test Split

# %%
x = data.drop(columns = 'selling_price')
y = data['selling_price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
len(y_train)
# Out:
# 3038

# %%
len(y_test)
# Out:
# 1302

# %%
len(x_test)
# Out:
# 1302

# %%
len(x_train)
# Out:
# 3038

# %% [markdown]
# ## Step 10 Model Development

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Step 11 Predictions

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([222092.22059131, 838497.19401764, 183257.54426816, ...,
#        541445.7718401 , 228944.69820593, 195825.73106053])

# %% [markdown]
# ## Step 12 Accuracy

# %%
accuracy = 100*r2_score(y_test, y_pred)
accuracy
# Out:
# 57.81778584459413

# %%
models = [LinearRegression(), Lasso(), ElasticNet(), KNeighborsRegressor(),
         DecisionTreeRegressor(), RandomForestRegressor(), AdaBoostRegressor(),
          GradientBoostingRegressor()]

# %%
acc_dic = {}

# %%
for model in models:
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    accuracy = 100* r2_score(y_test, y_pred)
    acc_dic[model] = round(accuracy,2)

# %%
acc_dic
# Out:
# {LinearRegression(): 57.82,
#  Lasso(): 57.82,
#  ElasticNet(): 47.21,
#  KNeighborsRegressor(): 39.11,
#  DecisionTreeRegressor(): 79.79,
#  RandomForestRegressor(): 85.48,
#  AdaBoostRegressor(): 25.76,
#  GradientBoostingRegressor(): 86.71}
